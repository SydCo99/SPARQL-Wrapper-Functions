# %%
from SPARQLWrapper import SPARQLWrapper, XML, JSON
import pandas as pd

# %%
#hard code the source for the example
source = "http://sparql.hegroup.org/sparql/"

# %%
def general_annotations(source):
    sparql = SPARQLWrapper(source)
    sparql.setReturnFormat(JSON)
    sparql.setQuery("""
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    SELECT DISTINCT ?p ?o 
    FROM <http://purl.obolibrary.org/obo/merged/OAE>
    WHERE
    {
    # ?s a owl:Ontology.
    # ?s ?p ?o .
    }
    """)
    try: 
        ret = sparql.queryAndConvert()
        results = []
        for r in ret["results"]["bindings"]:
            results.append(r)
        p = []
        o = []
        for result in results:
            p.append(result["p"]["value"])
            o.append(result["o"]["value"])
        df = pd.DataFrame({"p": p, "o":o})
        pd.set_option('display.max_rows', None)
            
        return df 
    except:
        print("oh noes!")

# %%
general_annotations(source)
# Out:
#                                                   p  \
# 0   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1         http://www.w3.org/2002/07/owl#versionInfo
# 2       http://purl.org/dc/elements/1.1/contributor
# 3       http://purl.org/dc/elements/1.1/contributor
# 4       http://purl.org/dc/elements/1.1/contributor
# 5       http://purl.org/dc/elements/1.1/contributor
# 6       http://purl.org/dc/elements/1.1/contributor
# 7       http://purl.org/dc/elements/1.1/contributor
# 8       http://purl.org/dc/elements/1.1/contributor
# 9       http://purl.org/dc/elements/1.1/description
# 10           http://purl.org/dc/elements/1.1/format
# 11          http://purl.org/dc/elements/1.1/license
# 12          http://purl.org/dc/elements/1.1/subject
# 13            http://purl.org/dc/elements/1.1/title
# 14       http://purl.obolibrary.org/obo/IAO_0000116
# 15          http://purl.org/dc/elements/1.1/creator
# 16          http://purl.org/dc/elements/1.1/creator
# 17          http://purl.org/dc/elements/1.1/creator
# 18          http://purl.org/dc/elements/1.1/creator
# 19          http://purl.org/dc/elements/1.1/creator
# 20          http://purl.org/dc/elements/1.1/creator
# 21          http://purl.org/dc/elements/1.1/creator
# 22          http://purl.org/dc/elements/1.1/creator
# 23          http://purl.org/dc/elements/1.1/creator
# 24          http://purl.org/dc/elements/1.1/creator
# 25          http://purl.org/dc/elements/1.1/creator
# 26          http://purl.org/dc/elements/1.1/creator
# 27          http://purl.org/dc/elements/1.1/creator
# 28          http://purl.org/dc/elements/1.1/creator
# 29          http://purl.org/dc/elements/1.1/creator
# 30          http://purl.org/dc/elements/1.1/creator
# 31          http://purl.org/dc/elements/1.1/creator
# 32          http://purl.org/dc/elements/1.1/creator
# 33          http://purl.org/dc/elements/1.1/creator
# 34          http://purl.org/dc/elements/1.1/creator
# 35          http://purl.org/dc/elements/1.1/creator
# 36          http://purl.org/dc/elements/1.1/creator
# 37          http://purl.org/dc/elements/1.1/creator
# 38          http://purl.org/dc/elements/1.1/creator
# 39             http://purl.org/dc/elements/1.1/date
#
#                                                     o
# 0              http://www.w3.org/2002/07/owl#Ontology
# 1                                              1.2.47
# 2                                 Mathias Brochhausen
# 3                                Darrell R. Abernethy
# 4                                     Elizabeth Blair
# 5                                  Izabela Birsanescu
# 6                                      Keith Burkhart
# 7                                          Luca Toldo
# 8                                       Sydni Joubran
# 9   The Ontology of Adverse Eventsy (OAE) is a bio...
# 10                                             OWL-DL
# 11        http://creativecommons.org/licenses/by/3.0/
# 12  An ontology for the annotation of the adverse ...
# 13                    OAE: Ontology of Adverse Events
# 14                                    Product version
# 15                                        Barry Smith
# 16                                        Jiangan Xie
# 17                                    "Asiyah" Yu Lin
# 18                                           Abra Guo
# 19                                      Bingjian Yang
# 20                                Desikan Jagannathan
# 21                                         Edison Ong
# 22                                         Kelly Yang
# 23                                           Kevin Mo
# 24                                         Liwei Wang
# 25                                          Meiu Wong
# 26                                         Noemi Garg
# 27                                       Qingping Liu
# 28                                       Rebecca Racz
# 29                                      Shelley Zhang
# 30                                Sirarat Sarntivijai
# 31                                      Sydni Joubran
# 32                           Yongqun "Oliver" He (YH)
# 33                            Zuoshuang "Allen" Xiang
# 34                                           Ling Wan
# 35                                   David Ameriguian
# 36                                    Jessica DeGuise
# 37                                Jiangan "Hardy" Xie
# 38                                        Qiuyue Yang
# 39                                          2022-8-15
