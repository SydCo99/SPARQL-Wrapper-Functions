# %%
from SPARQLWrapper import SPARQLWrapper, XML, JSON
import xml.dom.minidom

# %%
source = "http://sparql.hegroup.org/sparql/"

# %%
def find_all_subclasses(source):
    sparql = SPARQLWrapper(source)
    sparql.setReturnFormat(XML)
    sparql.setQuery("""
    PREFIX obo-term: <http://purl.obolibrary.org/obo/>
    SELECT DISTINCT ?x ?label
    WHERE
    {
    # ?x rdfs:subClassOf obo-term:OAE_0000001.
    # ?x rdfs:label  ?label.
    }
    """)
    results = sparql.query().convert()
    print(results.toxml())

# %%
find_all_subclasses(source)
# Out:
# <?xml version="1.0" ?><sparql xmlns="http://www.w3.org/2005/sparql-results#" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.w3.org/2001/sw/DataAccess/rf1/result2.xsd">
#  <head>
#   <variable name="x"/>
#   <variable name="label"/>
#  </head>
#  <results distinct="false" ordered="true">
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000003</uri></binding>
#    <binding name="label"><literal>causal adverse event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000004</uri></binding>
#    <binding name="label"><literal>vaccine adverse event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000008</uri></binding>
#    <binding name="label"><literal>nutritional product adverse event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000027</uri></binding>
#    <binding name="label"><literal>musculoskeletal or connective tissue AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000040</uri></binding>
#    <binding name="label"><literal>procedural complication AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000041</uri></binding>
#    <binding name="label"><literal>injury AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000052</uri></binding>
#    <binding name="label"><literal>tumor AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000053</uri></binding>
#    <binding name="label"><literal>wheezing AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000063</uri></binding>
#    <binding name="label"><literal>systematic AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000063</uri></binding>
#    <binding name="label"><literal>systematic adverse event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000069</uri></binding>
#    <binding name="label"><literal xml:lang="en">metabolism, endocrine or exocrine system AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000070</uri></binding>
#    <binding name="label"><literal>clinical trial adverse event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000100</uri></binding>
#    <binding name="label"><literal>influenza like illness AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000199</uri></binding>
#    <binding name="label"><literal>hair, skin or nail AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000204</uri></binding>
#    <binding name="label"><literal>congenital AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000208</uri></binding>
#    <binding name="label"><literal>abdominal AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000209</uri></binding>
#    <binding name="label"><literal>genetic AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000211</uri></binding>
#    <binding name="label"><literal>ulcer AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000214</uri></binding>
#    <binding name="label"><literal>sclerosis AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000219</uri></binding>
#    <binding name="label"><literal>prenatal, perinatal or neonatal disorder AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000226</uri></binding>
#    <binding name="label"><literal xml:lang="en">medical intervention site AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000361</uri></binding>
#    <binding name="label"><literal>fever AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000363</uri></binding>
#    <binding name="label"><literal>infection AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000364</uri></binding>
#    <binding name="label"><literal>syndrome AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000378</uri></binding>
#    <binding name="label"><literal>respiratory system AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000388</uri></binding>
#    <binding name="label"><literal>dizziness AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000400</uri></binding>
#    <binding name="label"><literal>syncope AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000429</uri></binding>
#    <binding name="label"><literal>Guillain-Barre syndrome AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000436</uri></binding>
#    <binding name="label"><literal>hepatobiliary or pancreatic AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000439</uri></binding>
#    <binding name="label"><literal>digestive system AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000443</uri></binding>
#    <binding name="label"><literal>eye AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000465</uri></binding>
#    <binding name="label"><literal>ear  AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000476</uri></binding>
#    <binding name="label"><literal>immune system AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000481</uri></binding>
#    <binding name="label"><literal>multiple sclerosis AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000493</uri></binding>
#    <binding name="label"><literal>cardiovascular AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000555</uri></binding>
#    <binding name="label"><literal>homeostasis AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000570</uri></binding>
#    <binding name="label"><literal>nervous system AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000574</uri></binding>
#    <binding name="label"><literal>gustatory system AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000580</uri></binding>
#    <binding name="label"><literal>behavioral and neurological AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000588</uri></binding>
#    <binding name="label"><literal>hematopoietic system AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000619</uri></binding>
#    <binding name="label"><literal>hematuria AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000622</uri></binding>
#    <binding name="label"><literal>urinary system AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000628</uri></binding>
#    <binding name="label"><literal xml:lang="en">investigation result abnormal AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000632</uri></binding>
#    <binding name="label"><literal>death AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000638</uri></binding>
#    <binding name="label"><literal>non-serious adverse event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000651</uri></binding>
#    <binding name="label"><literal>reproductive system AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0001348</uri></binding>
#    <binding name="label"><literal>purulent discharge AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0001438</uri></binding>
#    <binding name="label"><literal>suspiciousness AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0001551</uri></binding>
#    <binding name="label"><literal xml:lang="en">brain AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0001551</uri></binding>
#    <binding name="label"><literal>brain AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0002475</uri></binding>
#    <binding name="label"><literal xml:lang="en">therapy adverse event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0002625</uri></binding>
#    <binding name="label"><literal xml:lang="en">local AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0002626</uri></binding>
#    <binding name="label"><literal xml:lang="en">injury or procedural complication AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0002626</uri></binding>
#    <binding name="label"><literal xml:lang="en">obsolete: injury or procedural complication AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0002659</uri></binding>
#    <binding name="label"><literal>flank pain AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0004330</uri></binding>
#    <binding name="label"><literal xml:lang="en">nutritional disorder AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/GSSO_000079</uri></binding>
#    <binding name="label"><literal xml:lang="en">adverse drug event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0008852</uri></binding>
#    <binding name="label"><literal>critical illness AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000005</uri></binding>
#    <binding name="label"><literal xml:lang="en">adverse drug event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000005</uri></binding>
#    <binding name="label"><literal>adverse drug event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000631</uri></binding>
#    <binding name="label"><literal>severe adverse event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/OAE_0000631</uri></binding>
#    <binding name="label"><literal>serious adverse event</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/ODNAE_0000001</uri></binding>
#    <binding name="label"><literal xml:lang="en">drug-associated neuropathy AE</literal></binding>
#   </result>
#   <result>
#    <binding name="x"><uri>http://purl.obolibrary.org/obo/VICO_0100009</uri></binding>
#    <binding name="label"><literal xml:lang="en">serious vaccine adverse event</literal></binding>
#   </result>
#  </results>
# </sparql>

# %%
def find_all_subclasses(source):
    sparql = SPARQLWrapper(source)
    sparql.setReturnFormat(JSON)
    sparql.setQuery("""
    PREFIX obo-term: <http://purl.obolibrary.org/obo/>
    SELECT DISTINCT ?x ?label
    WHERE
    {
    # ?x rdfs:subClassOf obo-term:OAE_0000001.
    # ?x rdfs:label  ?label.
    }
    """)
    try: 
        ret = sparql.queryAndConvert()
        for r in ret["results"]["bindings"]:
                print(r)    
    except: 
        print("Oh Noes!")

# %%
find_all_subclasses(source)
# Out:
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000003'}, 'label': {'type': 'literal', 'value': 'causal adverse event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000004'}, 'label': {'type': 'literal', 'value': 'vaccine adverse event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000008'}, 'label': {'type': 'literal', 'value': 'nutritional product adverse event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000027'}, 'label': {'type': 'literal', 'value': 'musculoskeletal or connective tissue AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000040'}, 'label': {'type': 'literal', 'value': 'procedural complication AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000041'}, 'label': {'type': 'literal', 'value': 'injury AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000052'}, 'label': {'type': 'literal', 'value': 'tumor AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000053'}, 'label': {'type': 'literal', 'value': 'wheezing AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000063'}, 'label': {'type': 'literal', 'value': 'systematic AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000063'}, 'label': {'type': 'literal', 'value': 'systematic adverse event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000069'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'metabolism, endocrine or exocrine system AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000070'}, 'label': {'type': 'literal', 'value': 'clinical trial adverse event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000100'}, 'label': {'type': 'literal', 'value': 'influenza like illness AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000199'}, 'label': {'type': 'literal', 'value': 'hair, skin or nail AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000204'}, 'label': {'type': 'literal', 'value': 'congenital AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000208'}, 'label': {'type': 'literal', 'value': 'abdominal AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000209'}, 'label': {'type': 'literal', 'value': 'genetic AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000211'}, 'label': {'type': 'literal', 'value': 'ulcer AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000214'}, 'label': {'type': 'literal', 'value': 'sclerosis AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000219'}, 'label': {'type': 'literal', 'value': 'prenatal, perinatal or neonatal disorder AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000226'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'medical intervention site AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000361'}, 'label': {'type': 'literal', 'value': 'fever AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000363'}, 'label': {'type': 'literal', 'value': 'infection AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000364'}, 'label': {'type': 'literal', 'value': 'syndrome AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000378'}, 'label': {'type': 'literal', 'value': 'respiratory system AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000388'}, 'label': {'type': 'literal', 'value': 'dizziness AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000400'}, 'label': {'type': 'literal', 'value': 'syncope AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000429'}, 'label': {'type': 'literal', 'value': 'Guillain-Barre syndrome AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000436'}, 'label': {'type': 'literal', 'value': 'hepatobiliary or pancreatic AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000439'}, 'label': {'type': 'literal', 'value': 'digestive system AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000443'}, 'label': {'type': 'literal', 'value': 'eye AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000465'}, 'label': {'type': 'literal', 'value': 'ear  AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000476'}, 'label': {'type': 'literal', 'value': 'immune system AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000481'}, 'label': {'type': 'literal', 'value': 'multiple sclerosis AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000493'}, 'label': {'type': 'literal', 'value': 'cardiovascular AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000555'}, 'label': {'type': 'literal', 'value': 'homeostasis AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000570'}, 'label': {'type': 'literal', 'value': 'nervous system AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000574'}, 'label': {'type': 'literal', 'value': 'gustatory system AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000580'}, 'label': {'type': 'literal', 'value': 'behavioral and neurological AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000588'}, 'label': {'type': 'literal', 'value': 'hematopoietic system AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000619'}, 'label': {'type': 'literal', 'value': 'hematuria AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000622'}, 'label': {'type': 'literal', 'value': 'urinary system AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000628'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'investigation result abnormal AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000632'}, 'label': {'type': 'literal', 'value': 'death AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000638'}, 'label': {'type': 'literal', 'value': 'non-serious adverse event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000651'}, 'label': {'type': 'literal', 'value': 'reproductive system AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0001348'}, 'label': {'type': 'literal', 'value': 'purulent discharge AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0001438'}, 'label': {'type': 'literal', 'value': 'suspiciousness AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0001551'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'brain AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0001551'}, 'label': {'type': 'literal', 'value': 'brain AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0002475'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'therapy adverse event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0002625'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'local AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0002626'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'injury or procedural complication AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0002626'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'obsolete: injury or procedural complication AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0002659'}, 'label': {'type': 'literal', 'value': 'flank pain AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0004330'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'nutritional disorder AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/GSSO_000079'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'adverse drug event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0008852'}, 'label': {'type': 'literal', 'value': 'critical illness AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000005'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'adverse drug event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000005'}, 'label': {'type': 'literal', 'value': 'adverse drug event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000631'}, 'label': {'type': 'literal', 'value': 'severe adverse event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/OAE_0000631'}, 'label': {'type': 'literal', 'value': 'serious adverse event'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/ODNAE_0000001'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'drug-associated neuropathy AE'}}
# {'x': {'type': 'uri', 'value': 'http://purl.obolibrary.org/obo/VICO_0100009'}, 'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'serious vaccine adverse event'}}
